# %%
import folium
from folium.plugins import HeatMap
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# %%
accident = pd.read_csv('dataset\\uk_road_accident.csv')

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mean())
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mean())
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].fillna(accident['Road_Surface_Conditions'].mode()[0])
accident['Road_Type'] = accident['Road_Type'].fillna(accident['Road_Type'].mode()[0])
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mode()[0])
accident['Weather_Conditions'] = accident['Weather_Conditions'].fillna(accident['Weather_Conditions'].mode()[0])

# %%
accident['Accident Date'] = accident['Accident Date'].str.strip()
accident['Accident Date'] = accident['Accident Date'].astype('str')
accident['Accident Date'] = accident['Accident Date'].str.replace('/','-')
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'],dayfirst = True, errors = 'coerce')

# %%
accident['Year'] = accident['Accident Date'].dt.year
accident['Month'] = accident['Accident Date'].dt.month
accident['Day'] = accident['Accident Date'].dt.day
accident['DayOfWeek'] = accident['Accident Date'].dt.dayofweek

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  datetime64[ns]
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  660679 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       660679 non-null  object
#  13  Vehicle_Type             660679 non-null  object
#  14  Year                     660679 non-null  int32
#  15  Month                    660679 non-null  int32
#  16  Day                      660679 non-null  int32
#  17  DayOfWeek                660679 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(4), int64(2), object(9)
# memory usage: 80.6+ MB

# %% [markdown]
# <h1>STEP 1) Extract Latitude and Longitude from the DataFrame </h1>

# %%
london_df = accident[accident['District Area'] == 'City of London']

# %%
locations = list(zip(london_df['Latitude'], london_df['Longitude']))

# %% [markdown]
# <h1>STEP 2) Create a base app centered in a specific location</h1>

# %%
m = folium.Map(location=[london_df['Latitude'].mean(), london_df['Longitude'].mean()], zoom_start=10)

# %% [markdown]
# <h1>STEP 3) Add the heatmap layer</h1>

# %%
HeatMap(locations).add_to(m)

# %% [markdown]
# <h1>STEP 4) Save or Displat the map</h1>

# %%
m.save('accident_heatmap.htm')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map
#        'Wansbeck', 'Alnwick', 'Wear Valley', 'Sedgefield', 'Durham',
#        'Easington', 'Chester-le-Street', 'Derwentside', 'Teesdale',
#        'Darlington', 'Craven', 'Hambleton', 'Richmondshire', 'York',
#        'Harrogate', 'Selby', 'Scarborough', 'Ryedale', 'Kirklees',
#        'Leeds', 'Wakefield', 'Bradford', 'Calderdale', 'Doncaster',
#        'Barnsley', 'Sheffield', 'Rotherham', 'North East Lincolnshire',
#        'North Lincolnshire', 'East Riding of Yorkshire',
#        'Kingston upon Hull, City of', 'Redcar and Cleveland',
#        'Hartlepool', 'Middlesbrough', 'Stockton-on-Tees', 'Birmingham',
#        'Wolverhampton', 'Walsall', 'Dudley', 'Sandwell', 'Solihull',
#        'Coventry', 'Newcastle-under-Lyme', 'Stafford',
#        'East Staffordshire', 'South Staffordshire', 'Lichfield',
#        'Stoke-on-Trent', 'Cannock Chase', 'Tamworth',
#        'Staffordshire Moorlands', 'Malvern Hills', 'Worcester',
#        'Wychavon', 'Wyre Forest', 'Redditch', 'Bromsgrove',
#        'Herefordshire, County of', 'Telford and Wrekin',
#        'South Shropshire', 'Bridgnorth', 'Shrewsbury and Atcham',
#        'North Shropshire', 'Oswestry', 'Warwick', 'Stratford-upon-Avon',
#        'Rugby', 'North Warwickshire', 'Nuneaton and Bedworth',
#        'Amber Valley', 'Erewash', 'Bolsover', 'High Peak',
#        'Derbyshire Dales', 'North East Derbyshire', 'Chesterfield',
#        'Derby', 'South Derbyshire', 'Ashfield', 'Mansfield',
#        'Newark and Sherwood', 'Bassetlaw', 'Gedling', 'Rushcliffe',
#        'Nottingham', 'Broxtowe', 'South Holland', 'South Kesteven',
#        'North Kesteven', 'East Lindsey', 'Boston', 'West Lindsey',
#        'Lincoln', 'Hinckley and Bosworth', 'Harborough', 'Leicester',
#        'Rutland', 'Charnwood', 'Melton', 'North West Leicestershire',
#        'Blaby', 'Oadby and Wigston', 'South Northamptonshire',
#        'Northampton', 'Kettering', 'Corby', 'Daventry',
#        'East Northamptonshire', 'Wellingborough', 'South Cambridgeshire',
#        'Fenland', 'Huntingdonshire', 'Peterborough',
#        'East Cambridgeshire', 'Cambridge', "King's Lynn and West Norfolk",
#        'Norwich', 'Breckland', 'South Norfolk', 'Broadland',
#        'Great Yarmouth', 'North Norfolk', 'St. Edmundsbury', 'Babergh',
#        'Mid Suffolk', 'Forest Heath', 'Suffolk Coastal', 'Ipswich',
#        'Waveney', 'Luton', 'Mid Bedfordshire', 'Bedford',
#        'South Bedfordshire', 'East Hertfordshire', 'North Hertfordshire',
#        'Welwyn Hatfield', 'St. Albans', 'Hertsmere', 'Three Rivers',
#        'Watford', 'Dacorum', 'Broxbourne', 'Stevege', 'Stevenage',
#        'Epping Forest', 'Brentwood', 'Castle Point', 'Uttlesford',
#        'Chelmsford', 'Basildon', 'Tendring', 'Colchester', 'Thurrock',
#        'Braintree', 'Rochford', 'Maldon', 'Southend-on-Sea', 'Harlow',
#        'Aylesbury Vale', 'Wycombe', 'South Bucks', 'Chiltern', 'Slough',
#        'Windsor and Maidenhead', 'South Oxfordshire', 'Milton Keynes',
#        'Cherwell', 'Vale of White Horse', 'West Oxfordshire', 'Oxford',
#        'Reading', 'West Berkshire', 'Wokingham', 'Bracknell Forest',
#        'Eastleigh', 'Test Valley', 'Portsmouth', 'Winchester',
#        'Basingstoke and Deane', 'Southampton', 'Fareham', 'Hart',
#        'Gosport', 'Havant', 'Isle of Wight', 'East Hampshire', 'Rushmoor',
#        'New Forest', 'Elmbridge', 'Mole Valley', 'Guildford',
#        'Spelthorne', 'Epsom and Ewell', 'Runnymede', 'Woking',
#        'Reigate and Banstead', 'Surrey Heath', 'Waverley', 'Tandridge',
#        'Medway', 'Thanet', 'Shepway', 'Ashford', 'Maidstone', 'Dover',
#        'Tunbridge Wells', 'Canterbury', 'Tonbridge and Malling', 'Swale',
#        'Dartford', 'Sevenoaks', 'Gravesham', 'Brighton and Hove',
#        'Chichester', 'Rother', 'Lewes', 'Wealden', 'Eastbourne',
#        'Hastings', 'Crawley', 'Horsham', 'Mid Sussex', 'Arun', 'Adur',
#        'Worthing', 'Kerrier', 'Restormel', 'Carrick', 'Penwith',
#        'North Cornwall', 'West Devon', 'Torridge', 'Caradon',
#        'North Devon', 'Mid Devon', 'Exeter', 'East Devon', 'Teignbridge',
#        'Plymouth', 'South Hams', 'Torbay', 'Bristol, City of',
#        'South Somerset', 'Sedgemoor', 'Mendip', 'Taunton Deane',
#        'South Gloucestershire', 'North Somerset',
#        'Bath and North East Somerset', 'West Somerset', 'Stroud',
#        'Tewkesbury', 'Gloucester', 'Cotswold', 'Cheltenham',
#        'Forest of Dean', 'Salisbury', 'Kennet', 'West Wiltshire',
#        'North Wiltshire', 'Swindon', 'Bournemouth', 'Poole',
#        'East Dorset', 'West Dorset', 'Weymouth and Portland',
#        'Christchurch', 'Purbeck', 'North Dorset', 'Isle of Anglesey',
#        'Conwy', 'Denbighshire', 'Flintshire', 'Wrexham', 'Gwynedd',
#        'Monmouthshire', 'Newport', 'Caerphilly', 'Torfaen', 'Blaeu Gwent',
#        'Blaenau Gwent', 'Merthyr Tydfil', 'The Vale of Glamorgan',
#        'Cardiff', 'Rhondda, Cynon, Taff', 'Swansea', 'Bridgend',
#        'Neath Port Talbot', 'Carmarthenshire', 'Ceredigion',
#        'Pembrokeshire', 'Powys', 'Highland', 'Western Isles',
#        'Orkney Islands', 'Shetland Islands', 'Aberdeenshire', 'Moray',
#        'Aberdeen City', 'Dundee City', 'Angus', 'Perth and Kinross',
#        'Fife', 'East Lothian', 'Midlothian', 'Scottish Borders',
#        'Edinburgh, City of', 'West Lothian', 'Falkirk',
#        'Clackmannanshire', 'Stirling', 'Clackmannshire', 'Glasgow City',
#        'East Dunbartonshire', 'North Larkshire', 'North Lanarkshire',
#        'Renfrewshire', 'East Renfrewshire', 'East Ayrshire',
#        'South Larkshire', 'Inverclyde', 'West Dunbartonshire',
#        'Argyll and Bute', 'South Lanarkshire', 'North Ayrshire',
#        'South Ayrshire', 'Dumfries and Galloway', 'Cheshire East',
#        'Cheshire West and Chester', 'Northumberland', 'County Durham',
#        'Shropshire', 'Central Bedfordshire', 'Cornwall', 'Wiltshire'],
#       dtype=object)

# %% [markdown]
# <h1> 1) What is the number of accidents on the District of Bolton </h1>

# %%
from folium.plugins import HeatMap
import pandas as pd
import numpy as np

Bolton_df = accident[accident['District Area'] == 'Bolton']
Bolton_df_clean = Bolton_df.dropna(subset=['Latitude', 'Longitude'])
Bolton_locations = list(zip(Bolton_df_clean['Latitude'], Bolton_df_clean['Longitude']))
center_lat = Bolton_df_clean['Latitude'].mean()
center_lon = Bolton_df_clean['Longitude'].mean()

Bolton_m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)

HeatMap(
    locations,
    min_opacity=0.2,
    radius=15,
    blur=10,
    max_zoom=1
).add_to(Bolton_m) 
Bolton_m.save('london_accident_heatmap.html')
print("Heatmap created successfully!")
print(f"Map center: ({center_lat:.6f}, {center_lon:.6f})")
print(f"The number of accidents that happened on Bolton is: {len(locations):,}")
Bolton_m
# Out:
# Heatmap created successfully!
# Map center: (53.572276, -2.446266)
# The number of accidents that happened on Bolton is: 1,317
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3e1105d359d631df73f5c6c5c088e29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3e1105d359d631df73f5c6c5c088e29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3e1105d359d631df73f5c6c5c088e29 = L.map(
#                 &quot;map_e3e1105d359d631df73f5c6c5c088e29&quot;,
#                 {
#                     center: [53.57227567417678, -2.4462657105719234],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b211f1957337c6930368c255c8101690 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b211f1957337c6930368c255c8101690.addTo(map_e3e1105d359d631df73f5c6c5c088e29);
#
#
#             var heat_map_bb114e034867f626c78430cc3cdabb14 = L.heatLayer(
#                 [[51.510898, -0.102684], [51.515721, -0.10061], [51.509123, -0.087482], [51.518599, -0.100634], [51.508932, -0.081293], [51.513119, -0.089909], [51.517443, -0.084827], [51.514074, -0.104426], [51.51613, -0.081567], [51.51693, -0.080957], [51.510601, -0.084394], [51.513299, -0.089901], [51.513804, -0.104437], [51.514254, -0.104418], [51.514095, -0.094624], [51.520812, -0.092902], [51.515181, -0.089534], [51.513736, -0.111358], [51.516345, -0.08372], [51.511786, -0.085353], [51.511557, -0.082336], [51.513955, -0.075029], [51.517593, -0.105144], [51.514121, -0.107306], [51.517275, -0.096653], [51.510978, -0.107581], [51.513211, -0.090049], [51.51248, -0.094836], [51.513219, -0.079528], [51.510818, -0.08669], [51.51065, -0.092894], [51.511583, -0.08392], [51.510821, -0.086834], [51.518616, -0.079589], [51.514856, -0.075135], [51.509858, -0.08846], [51.512494, -0.0957], [51.51219, -0.088074], [51.508929, -0.081149], [51.513493, -0.090758], [51.518441, -0.085362], [51.511511, -0.090553], [51.50953, -0.079395], [51.511794, -0.096882], [
# Step 3: Create locations list (lat, lon pairs)
locations = list(zip(Camden_df_clean['Latitude'], Camden_df_clean['Longitude']))
# Step 4: Create the map
center_lat = Camden_df_clean['Latitude'].mean()
center_lon = Camden_df_clean['Longitude'].mean()

a = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)
# Step 5: Add heatmap
HeatMap(
    locations,
    min_opacity=0.2,
    radius=15,
    blur=10,
    max_zoom=1
).add_to(a) 
print("Heatmap created successfully!")
print(f"Map center: ({center_lat:.6f}, {center_lon:.6f})")
print(f"Total Severe accidents ( Fatal & Serious ) : {len(locations):,}")
a
# Out:
# Heatmap created successfully!
# Map center: (51.535689, -0.143146)
# Total Severe accidents ( Fatal & Serious ) : 116
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f3605c794995c6df0ef8f2b57476d05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f3605c794995c6df0ef8f2b57476d05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f3605c794995c6df0ef8f2b57476d05 = L.map(
#                 &quot;map_1f3605c794995c6df0ef8f2b57476d05&quot;,
#                 {
#                     center: [51.535689146551725, -0.1431460689655172],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f05756740bd12ea082468e520ccd83e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f05756740bd12ea082468e520ccd83e.addTo(map_1f3605c794995c6df0ef8f2b57476d05);
#
#
#             var heat_map_ad714a0dcb5c0cca5b593bd4afdefd1a = L.heatLayer(
#                 [[51.533556, -0.147449], [51.528613, -0.119392], [51.551439, -0.140953], [51.517013, -0.13068], [51.52977, -0.124247], [51.518147, -0.111608], [51.517728, -0.130363], [51.535503, -0.128481], [51.524613, -0.127918], [51.531809, -0.139302], [51.529429, -0.125414], [51.557329, -0.195677], [51.531377, -0.146096], [51.539934, -0.135654], [51.532607, -0.127302], [51.550207, -0.182833], [51.540192, -0.140546], [51.519669, -0.105635], [51.523399, -0.130707], [51.54947, -0.175939], [51.547491, -0.141547], [51.548053, -0.200659], [51.542085, -0.146526], [51.555954, -0.147838], [51.540452, -0.139959], [51.520993, -0.115238], [51.538786, -0.142623], [51.537327, -0.141384], [51.534086, -0.129837], [51.528996, -0.126441], [51.516534, -0.128826], [51.521316, -0.124162], [51.549568, -0.153434], [51.537081, -0.137212], [51.542857, -0.144187], [51.538021, -0.151162], [51.526405, -0.138802], [51.522691, -0.125835], [51.51694, -0.126071], [51.537504, -0.193], [51.520883, -0.125189], [51.541718, -0.134716], [51.521412, -0.113347], [51.524208, -0.125052], [51.528653, -0.127464], [51.545568, -0.133693], [51.517387, -0.120287], [51.539137, -0.170728], [51.539772, -0.142438], [51.520398, -0.117425], [51.517391, -0.120575], [51.539401, -0.141732], [51.530657, -0.134735], [51.543206, -0.149221], [51.553904, -0.154701], [51.541744, -0.142069], [51.518364, -0.130769], [51.554755, -0.192028], [51.562566, -0.179599], [51.549546, -0.163531], [51.553687, -0.163797], [51.546475, -0.145482], [51.52955, -0.138673], [51.516617, -0.128391], [51.539332, -0.143033], [51.520124, -0.122769], [51.543839, -0.155108], [51.528991, -0.126153], [51.559735, -0.182597], [51.516377, -0.130274], [51.536314, -0.191606], [51.552519, -0.141053], [51.536714, -0.142418], [51.527268, -0.130837], [51.522007, -0.122403], [51.546415, -0.141735], [51.543029, -0.166534], [51.54364, -0.125551], [51.548089, -0.191283], [51.55197, -0.15752], [51.545985, -0.148675], [51.54565, -0.1559], [51.544973, -0.141505], [51.52424, -0.115824], [51.52573, -0.135946], [51.517774, -0.127622], [51.547558, -0.180198], [51.546, -0.143915], [51.538783, -0.142478], [51.530561, -0.123061], [51.524892, -0.122861], [51.518931, -0.121233], [51.555855, -0.175972], [51.550845, -0.183384], [51.543114, -0.14908], [51.52427, -0.128942], [51.525565, -0.125573], [51.542065, -0.179696], [51.524686, -0.138151], [51.520958, -0.113077], [51.537404, -0.134892], [51.523037, -0.119334], [51.520564, -0.116553], [51.539756, -0.141429], [51.540998, -0.192141], [51.554286, -0.144732], [51.543729, -0.159583], [51.521859, -0.135671], [51.524778, -0.138291], [51.557785, -0.178636], [51.546832, -0.179794], [51.518496, -0.105395], [51.542752, -0.137558], [51.553272, -0.194972], [51.557259, -0.179522], [51.520393, -0.105893]],
#                 {
#   &quot;minOpacity&quot;: 0.2,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 15,
#   &quot;blur&quot;: 10,
# }
#             );
#
#
#             heat_map_ad714a0dcb5c0cca5b593bd4afdefd1a.addTo(map_1f3605c794995c6df0ef8f2b57476d05);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h1> 3) What's the number of accidents during Raining and High winds in the city of Lancaster  </h1>

# %%
from folium.plugins import HeatMap
import folium

lancaster = accident[(accident['District Area'] == 'Lancaster')&(accident['Weather_Conditions'] == 'Raining + high winds')]
lancaster_df_clean = lancaster.dropna(subset=['Latitude', 'Longitude'])
locations = list(zip(lancaster_df_clean['Latitude'], lancaster_df_clean['Longitude']))
center_lat = lancaster_df_clean['Latitude'].mean()
center_lon = lancaster_df_clean['Longitude'].mean()

c = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)

HeatMap(
    locations,
    min_opacity=0.2,
    radius=15,
    blur=10,
    max_zoom=1
).add_to(c) 
c.save('lancaster_accident_heatmap.html')

print("Heatmap created successfully!")
print(f"Map center: ({center_lat:.6f}, {center_lon:.6f})")
print(f"Total accidents on Lancaster involving rain and high winds: {len(lancaster):,}")
c
# Out:
# Heatmap created successfully!
# Map center: (54.067294, -2.790350)
# Total accidents on Lancaster involving rain and high winds: 33
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_443064429cf1a2b31ddf4bfa9111b6b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_443064429cf1a2b31ddf4bfa9111b6b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_443064429cf1a2b31ddf4bfa9111b6b7 = L.map(
#                 &quot;map_443064429cf1a2b31ddf4bfa9111b6b7&quot;,
#                 {
#                     center: [54.06729433333333, -2.7903498484848486],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ecee0af9aadbaddd3f2ab36302ee7eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ecee0af9aadbaddd3f2ab36302ee7eb.addTo(map_443064429cf1a2b31ddf4bfa9111b6b7);
#
#
#             var heat_map_977eafa7baa52fc8719b3862b9ec7bd1 = L.heatLayer(
#                 [[54.035541, -2.763093], [53.981712, -2.789405], [54.052508, -2.766306], [54.045599, -2.894622], [54.062159, -2.879547], [54.060336, -2.858119], [54.106532, -2.765161], [54.045764, -2.76664], [54.045764, -2.76664], [54.167637, -2.73841], [54.032104, -2.794176], [54.066284, -2.880856], [54.142596, -2.73276], [54.137138, -2.757766], [54.056564, -2.870262], [54.109597, -2.763841], [54.078965, -2.701986], [54.04975, -2.803219], [54.120683, -2.651588], [54.061822, -2.888707], [54.075957, -2.860734], [54.077009, -2.771954], [54.140656, -2.741298], [54.124484, -2.75478], [54.007564, -2.780739], [54.073328, -2.771274], [53.961503, -2.759302], [54.079711, -2.771087], [54.051404, -2.797752], [54.008379, -2.793572], [54.05444, -2.840277], [54.05453, -2.840279], [54.052693, -2.765393]],
#                 {
#   &quot;minOpacity&quot;: 0.2,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 15,
#   &quot;blur&quot;: 10,
# }
#             );
#
#
#             heat_map_977eafa7baa52fc8719b3862b9ec7bd1.addTo(map_443064429cf1a2b31ddf4bfa9111b6b7);
#
#
#             tile_layer_7ecee0af9aadbaddd3f2ab36302ee7eb.addTo(map_443064429cf1a2b31ddf4bfa9111b6b7);
#
#
#             heat_map_977eafa7baa52fc8719b3862b9ec7bd1.addTo(map_443064429cf1a2b31ddf4bfa9111b6b7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h1> 4) The number of accidents that occured during on weekends vs weekdays on Burnley  </h1>

# %%
burnley = accident[
    (accident['District Area'] == 'Burnley') &
    (~accident['DayOfWeek'].isin(['Saturday', 'Sunday']))
]
burnley_df_clean = burnley.dropna(subset=['Latitude', 'Longitude'])
burnley_locations = list(zip(burnley_df_clean['Latitude'], burnley_df_clean['Longitude']))
burnley_center_lat = burnley_df_clean['Latitude'].mean()
burnley_locations = list(zip(burnley_df_clean['Latitude'], burnley_df_clean['Longitude']))
burnley_center_lat = burnley_df_clean['Latitude'].mean()
burnley_center_lon = burnley_df_clean['Longitude'].mean()

burnley_m = folium.Map(
    location=[burnley_center_lat, burnley_center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)

HeatMap(
    burnley_locations,
    min_opacity=0.2,
    radius=15,
    blur=10,
    max_zoom=1
).add_to(burnley_m) 

print("Heatmap created successfully!")
print(f"Map center: ({center_lat:.6f}, {center_lon:.6f})")
burnley_m
# Out:
# Heatmap created successfully!
# Map center: (54.067294, -2.790350)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6262bd2ad21afb9fe77fce99e9ce77c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6262bd2ad21afb9fe77fce99e9ce77c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6262bd2ad21afb9fe77fce99e9ce77c = L.map(
#                 &quot;map_f6262bd2ad21afb9fe77fce99e9ce77c&quot;,
#                 {
#                     center: [53.790358216476776, -2.2550693838737947],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1398cd59ec8282a68f21e3fdab7c54ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer
2.151166], [53.788796, -2.263015], [53.804851, -2.236238], [53.811955, -2.234456], [53.802426, -2.235314], [53.785684, -2.247514], [53.796754, -2.239988], [53.795779, -2.232999], [53.785871, -2.244024], [53.801254, -2.236977], [53.808619, -2.239904], [53.808181, -2.234283], [53.810696, -2.234753], [53.788333, -2.225976], [53.800013, -2.228164], [53.802773, -2.241693], [53.792345, -2.242544], [53.79, -2.246477], [53.803252, -2.226512], [53.790888, -2.251491], [53.800828, -2.225132], [53.791903, -2.238746], [53.800902, -2.233331], [53.783995, -2.238094], [53.785058, -2.245689], [53.814619, -2.25057], [53.785086, -2.231878], [53.788037, -2.23918], [53.79754, -2.251227], [53.80745, -2.239897], [53.806307, -2.227287], [53

# %% [markdown]
# <h1> 5) Which districts experience more severe accidents on Richmond upon tames, using cars </h1>

# %%
R_df = accident[(accident['District Area'] == 'Richmond upon Thames') & (accident['Vehicle_Type'] =='Car') & (accident['Accident_Severity'] !='Slight')]
R_df_clean = R_df.dropna(subset=['Latitude', 'Longitude'])
R_locations = list(zip(R_df_clean['Latitude'], R_df_clean['Longitude']))
R_center_lat = R_df_clean['Latitude'].mean()
R_center_lon = R_df_clean['Longitude'].mean()

R_m = folium.Map(
    location=[R_center_lat, R_center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)

HeatMap(
    R_locations,
    min_opacity=0.2,
    radius=15,
    blur=10,
    max_zoom=1
).add_to(R_m) 
R_m.save('london_accident_heatmap.html')
print("Heatmap created successfully!")
print(f"Map center: ({center_lat:.6f}, {center_lon:.6f})")
print(f"The number of accidents that happened on Bolton is: {len(locations):,}")
R_m
# Out:
# Heatmap created successfully!
# Map center: (54.067294, -2.790350)
# The number of accidents that happened on Bolton is: 33
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc8c2d76b348127b8695fdda2c360d5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc8c2d76b348127b8695fdda2c360d5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc8c2d76b348127b8695fdda2c360d5f = L.map(
#                 &quot;map_fc8c2d76b348127b8695fdda2c360d5f&quot;,
#                 {
#                     center: [51.44938937362637, -0.31144605494505495],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05d58a7738baa61684227b46b6364ba0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05d58a7738baa61684227b46b6364ba0.addTo(map_fc8c2d76b348127b8695fdda2c360d5f);
#
#
#             var heat_map_622049470d30180b9dc377ae16c92da4 = L.heatLayer(
#                 [[51.464775, -0.3027], [51.416832, -0.358695], [51.464989, -0.262093], [51.457071, -0.32357], [51.428756, -0.324319], [51.464298, -0.288465], [51.446785, -0.372156], [51.460677, -0.268447], [51.464028, -0.288475], [51.442728, -0.364962], [51.468985, -0.276915], [51.407576, -0.346374], [51.428712, -0.352947], [51.425984, -0.338085], [51.420486, -0.318293], [51.460001, -0.302157], [51.452525, -0.358135], [51.462703, -0.302489], [51.445821, -0.329162], [51.442639, -0.364965], [51.436594, -0.312809], [51.451577, -0.298008], [51.412536, -0.360143], [51.439313, -0.333141], [51.455616, -0.354138], [51.453771, -0.338084], [51.458205, -0.296178], [51.430766, -0.345536], [51.485507, -